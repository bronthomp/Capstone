# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
#Import csv's for 3 required datasets
social = pd.read_csv(r'C:\Users\brthompson\bt_school\data\raw\social_support.csv', usecols = ['SUBJECT_ID', 'HADM_ID', 'ICUSTAY_ID', 'ITEMID', 'CHARTTIME', 'CGID', 'VALUE'])
pat = pd.read_csv(r'C:\Users\brthompson\bt_school\data\raw\PATIENTS.csv')
admit = pd.read_csv(r'C:\Users\brthompson\bt_school\data\raw\ADMISSIONS.csv')

# %%
#Examine first dataset
social.head()
# Out:
#    SUBJECT_ID  HADM_ID  ICUSTAY_ID  ITEMID            CHARTTIME     CGID  \
# 0           4   185777    294638.0     663  2191-03-16 08:00:00  18692.0
# 1          28   162569    225559.0     663  2177-09-01 23:00:00  17130.0
# 2          21   111970    216859.0     663  2135-02-02 20:00:00  14206.0
# 3           6   107064    228232.0     663  2175-06-03 03:00:00  17461.0
# 4          17   194023    277042.0     663  2134-12-29 04:00:00  19963.0
#
#       VALUE
# 0  Relative
# 1  Relative
# 2    Spouse
# 3    Spouse
# 4    Spouse

# %%
#Examine second dataset
pat.head()
# Out:
#    ROW_ID  SUBJECT_ID GENDER                  DOB                  DOD  \
# 0     234         249      F  2075-03-13 00:00:00                  NaN
# 1     235         250      F  2164-12-27 00:00:00  2188-11-22 00:00:00
# 2     236         251      M  2090-03-15 00:00:00                  NaN
# 3     237         252      M  2078-03-06 00:00:00                  NaN
# 4     238         253      F  2089-11-26 00:00:00                  NaN
#
#               DOD_HOSP DOD_SSN  EXPIRE_FLAG
# 0                  NaN     NaN            0
# 1  2188-11-22 00:00:00     NaN            1
# 2                  NaN     NaN            0
# 3                  NaN     NaN            0
# 4                  NaN     NaN            0

# %%
#Examine third dataset
admit.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID            ADMITTIME            DISCHTIME  \
# 0      21          22   165315  2196-04-09 12:26:00  2196-04-10 15:54:00
# 1      22          23   152223  2153-09-03 07:15:00  2153-09-08 19:10:00
# 2      23          23   124321  2157-10-18 19:34:00  2157-10-25 14:00:00
# 3      24          24   161859  2139-06-06 16:14:00  2139-06-09 12:48:00
# 4      25          25   129635  2160-11-02 02:06:00  2160-11-05 14:55:00
#
#   DEATHTIME ADMISSION_TYPE         ADMISSION_LOCATION  \
# 0       NaN      EMERGENCY       EMERGENCY ROOM ADMIT
# 1       NaN       ELECTIVE  PHYS REFERRAL/NORMAL DELI
# 2       NaN      EMERGENCY  TRANSFER FROM HOSP/EXTRAM
# 3       NaN      EMERGENCY  TRANSFER FROM HOSP/EXTRAM
# 4       NaN      EMERGENCY       EMERGENCY ROOM ADMIT
#
#           DISCHARGE_LOCATION INSURANCE LANGUAGE           RELIGION  \
# 0  DISC-TRAN CANCER/CHLDRN H   Private      NaN       UNOBTAINABLE
# 1           HOME HEALTH CARE  Medicare      NaN           CATHOLIC
# 2           HOME HEALTH CARE  Medicare     ENGL           CATHOLIC
# 3                       HOME   Private      NaN  PROTESTANT QUAKER
# 4                       HOME   Private      NaN       UNOBTAINABLE
#
#   MARITAL_STATUS ETHNICITY            EDREGTIME            EDOUTTIME  \
# 0        MARRIED     WHITE  2196-04-09 10:06:00  2196-04-09 13:24:00
# 1        MARRIED     WHITE                  NaN                  NaN
# 2        MARRIED     WHITE                  NaN                  NaN
# 3         SINGLE     WHITE                  NaN                  NaN
# 4        MARRIED     WHITE  2160-11-02 01:01:00  2160-11-02 04:27:00
#
#                                            DIAGNOSIS  HOSPITAL_EXPIRE_FLAG  \
# 0                            BENZODIAZEPINE OVERDOSE                     0
# 1  CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS...                     0
# 2                                         BRAIN MASS                     0
# 3                     INTERIOR MYOCARDIAL INFARCTION                     0
# 4                            ACUTE CORONARY SYNDROME                     0
#
#    HAS_CHARTEVENTS_DATA
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1

# %%
#Drop ROW_ID column from pat and admit tables so that they do not interfere with merging - these are unique to the table rows
pat = pat.drop('ROW_ID', 1)
admit = admit.drop('ROW_ID', 1)

# %%
#Check tables after dropping
pat.head()
# Out:
#    SUBJECT_ID GENDER                  DOB                  DOD  \
# 0         249      F  2075-03-13 00:00:00                  NaN
# 1         250      F  2164-12-27 00:00:00  2188-11-22 00:00:00
# 2         251      M  2090-03-15 00:00:00                  NaN
# 3         252      M  2078-03-06 00:00:00                  NaN
# 4         253      F  2089-11-26 00:00:00                  NaN
#
#               DOD_HOSP DOD_SSN  EXPIRE_FLAG
# 0                  NaN     NaN            0
# 1  2188-11-22 00:00:00     NaN            1
# 2                  NaN     NaN            0
# 3                  NaN     NaN            0
# 4                  NaN     NaN            0

# %%
admit.head()
# Out:
#    SUBJECT_ID  HADM_ID            ADMITTIME            DISCHTIME DEATHTIME  \
# 0          22   165315  2196-04-09 12:26:00  2196-04-10 15:54:00       NaN
# 1          23   152223  2153-09-03 07:15:00  2153-09-08 19:10:00       NaN
# 2          23   124321  2157-10-18 19:34:00  2157-10-25 14:00:00       NaN
# 3          24   161859  2139-06-06 16:14:00  2139-06-09 12:48:00       NaN
# 4          25   129635  2160-11-02 02:06:00  2160-11-05 14:55:00       NaN
#
#   ADMISSION_TYPE         ADMISSION_LOCATION         DISCHARGE_LOCATION  \
# 0      EMERGENCY       EMERGENCY ROOM ADMIT  DISC-TRAN CANCER/CHLDRN H
# 1       ELECTIVE  PHYS REFERRAL/NORMAL DELI           HOME HEALTH CARE
# 2      EMERGENCY  TRANSFER FROM HOSP/EXTRAM           HOME HEALTH CARE
# 3      EMERGENCY  TRANSFER FROM HOSP/EXTRAM                       HOME
# 4      EMERGENCY       EMERGENCY ROOM ADMIT                       HOME
#
#   INSURANCE LANGUAGE           RELIGION MARITAL_STATUS ETHNICITY  \
# 0   Private      NaN       UNOBTAINABLE        MARRIED     WHITE
# 1  Medicare      NaN           CATHOLIC        MARRIED     WHITE
# 2  Medicare     ENGL           CATHOLIC        MARRIED     WHITE
# 3   Private      NaN  PROTESTANT QUAKER         SINGLE     WHITE
# 4   Private      NaN       UNOBTAINABLE        MARRIED     WHITE
#
#              EDREGTIME            EDOUTTIME  \
# 0  2196-04-09 10:06:00  2196-04-09 13:24:00
# 1                  NaN                  NaN
# 2                  NaN                  NaN
# 3                  NaN                  NaN
# 4  2160-11-02 01:01:00  2160-11-02 04:27:00
#
#                                            DIAGNOSIS  HOSPITAL_EXPIRE_FLAG  \
# 0                            BENZODIAZEPINE OVERDOSE                     0
# 1  CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS...                     0
# 2                                         BRAIN MASS                     0
# 3                     INTERIOR MYOCARDIAL INFARCTION                     0
# 4                            ACUTE CORONARY SYNDROME                     0
#
#    HAS_CHARTEVENTS_DATA
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1

# %%
#For social dataset, interested in the number of visitors they have, indicated by the number of rows in the social dataset. 
#Reshape this dataset to count number of visitors per patient stay (SUBJECT_ID and HADM_ID)
#Need only keep ID variables and Value count
soc = social.groupby(['SUBJECT_ID', 'HADM_ID', 'ICUSTAY_ID']).count()
soc = soc.drop(['ITEMID','CHARTTIME','CGID'],1)

# %%
#Merge the 3 datasets together by SUBJECT_ID
#Outer joins required 
socpat = pd.merge(pat, soc, how = 'outer', on = ['SUBJECT_ID'])
merged = pd.merge(socpat, admit, how = 'outer', on = ['SUBJECT_ID'])
merged.head()
# Out:
#    SUBJECT_ID GENDER                  DOB                  DOD  \
# 0         249      F  2075-03-13 00:00:00                  NaN
# 1         249      F  2075-03-13 00:00:00                  NaN
# 2         249      F  2075-03-13 00:00:00                  NaN
# 3         250      F  2164-12-27 00:00:00  2188-11-22 00:00:00
# 4         251      M  2090-03-15 00:00:00                  NaN
#
#               DOD_HOSP DOD_SSN  EXPIRE_FLAG  VALUE  HADM_ID  \
# 0                  NaN     NaN            0   35.0   116935
# 1                  NaN     NaN            0   35.0   149546
# 2                  NaN     NaN            0   35.0   158975
# 3  2188-11-22 00:00:00     NaN            1   60.0   124271
# 4                  NaN     NaN            0    9.0   117937
#
#              ADMITTIME  ... INSURANCE LANGUAGE       RELIGION MARITAL_STATUS  \
# 0  2149-12-17 20:41:00  ...  Medicare      NaN       CATHOLIC       DIVORCED
# 1  2155-02-03 20:16:00  ...  Medicare     ENGL       CATHOLIC       DIVORCED
# 2  2156-04-27 15:33:00  ...  Medicare     ENGL       CATHOLIC       DIVORCED
# 3  2188-11-12 09:22:00  ...  Self Pay     HAIT  NOT SPECIFIED         SINGLE
# 4  2110-07-27 06:46:00  ...   Private      NaN          OTHER            NaN
#
#                 ETHNICITY            EDREGTIME            EDOUTTIME  \
# 0                   WHITE  2149-12-17 11:10:00  2149-12-17 21:35:00
# 1                   WHITE  2155-02-03 17:43:00  2155-02-03 21:26:00
# 2                   WHITE                  NaN                  NaN
# 3  BLACK/AFRICAN AMERICAN  2188-11-12 06:56:00  2188-11-12 10:10:00
# 4   UNKNOWN/NOT SPECIFIED  2110-07-27 05:00:00  2110-07-27 07:15:00
#
#                            DIAGNOSIS HOSPITAL_EXPIRE_FLAG HAS_CHARTEVENTS_DATA
# 0  UNSTABLE ANGINA;ASTHMA;BRONCHITIS                    0                    1
# 1               GI BLEED/ CHEST PAIN                    0                    1
# 2            GI BLEEDING\COLONOSCOPY                    0                    1
# 3                   PNEUMONIA;R/O TB                    1                    1
# 4            INTRACRANIAL HEAD BLEED                    0                    1
#
# [5 rows x 25 columns]

# %%
merged.to_csv(r'C:\Users\brthompson\bt_school\data\interim\merged.csv', index=False)
